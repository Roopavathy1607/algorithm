# %% [markdown]
# <a href="https://colab.research.google.com/github/Roopavathy1607/algorithm/blob/main/mergeandquicksort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import matplotlib.pyplot as plt
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]
        merge_sort(L)
        merge_sort(R)
        i = j = k = 0
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1
        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[0]
        less = [x for x in arr[1:] if x < pivot]
        equal = [pivot]
        greater = [x for x in arr[1:] if x >= pivot]
        return quick_sort(less) + equal + quick_sort(greater)
def test_sorting_algorithms():
    sizes = [100, 500, 1000, 2000, 3000, 4000, 5000]
    merge_times = []
    quick_times = []
    for n in sizes:
        data = [random.randint(1, 10000) for _ in range(n)]
        merge_data = data.copy()
        start = time.time()
        merge_sort(merge_data)
        end = time.time()
        merge_times.append(end - start)
        quick_data = data.copy()
        start = time.time()
        quick_sort(quick_data)
        end = time.time()
        quick_times.append(end - start)
    plt.plot(sizes, merge_times, label="Merge Sort", marker='o')
    plt.plot(sizes, quick_times, label="Quick Sort", marker='x')
    plt.xlabel("Number of elements (n)")
    plt.ylabel("Time taken (seconds)")
    plt.title("Time Complexity of Merge Sort vs Quick Sort")
    plt.legend()
    plt.grid(True)
    plt.show()
test_sorting_algorithms()

# %%
import time
import random
import matplotlib.pyplot as plt
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]
        merge_sort(L)
        merge_sort(R)
        i = j = k = 0
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1
        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
def run_experiment():
    sizes = [100, 500, 1000, 2000, 3000, 4000, 5000]
    times = []
    for n in sizes:
        data = [random.randint(0, 10000) for _ in range(n)]
        start = time.time()
        merge_sort(data)
        end = time.time()
        times.append(end - start)
        print(f"Sorted {n} elements in {end - start:.6f} seconds")
    plt.plot(sizes, times, marker='o', color='blue')
    plt.xlabel("Number of elements (n)")
    plt.ylabel("Time taken (seconds)")
    plt.title("Merge Sort Time Complexity")
    plt.grid(True)
    plt.show()
run_experiment()
# Out:
# Sorted 100 elements in 0.000142 seconds
# Sorted 500 elements in 0.000801 seconds
# Sorted 1000 elements in 0.002230 seconds
# Sorted 2000 elements in 0.005129 seconds
# Sorted 3000 elements in 0.006607 seconds
# Sorted 4000 elements in 0.008822 seconds
# Sorted 5000 elements in 0.011535 seconds

# %%
import time
import random
import matplotlib.pyplot as plt
def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)
def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1
    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1
def run_experiment():
    sizes = [100, 500, 1000, 2000, 3000, 4000, 5000]
    times = []
    for n in sizes:
        data = [random.randint(0, 10000) for _ in range(n)]
        start = time.time()
        quick_sort(data, 0, len(data) - 1)
        end = time.time()
        elapsed = end - start
        times.append(elapsed)
        print(f"Sorted {n} elements in {elapsed:.6f} seconds")
    plt.plot(sizes, times, marker='x', color='red')
    plt.xlabel("Number of elements (n)")
    plt.ylabel("Time taken (seconds)")
    plt.title("Quick Sort Time Complexity")
    plt.grid(True)
    plt.show()
run_experiment()
# Out:
# Sorted 100 elements in 0.000157 seconds
# Sorted 500 elements in 0.001011 seconds
# Sorted 1000 elements in 0.002487 seconds
# Sorted 2000 elements in 0.005175 seconds
# Sorted 3000 elements in 0.006983 seconds
# Sorted 4000 elements in 0.011493 seconds
# Sorted 5000 elements in 0.012100 seconds
